# %% [markdown]
# # Data science tools and Ecosystem

# %% [markdown]
# This notebok provides an overview of Data Science Tools and its ecosystem.

# %% [markdown]
# some of the popular languages that data scientist use are:
#
# 1) python
#
# 2) R
#
# 3) Julia
#
# 4) SQL

# %% [markdown]
# The libraries that used by data scientist are listed bellows:
#
# 1) Pandas
#
# 2) numpy
#
# 3) scikit-learn
#
# 4) ggplot2
#
# 5) dplyr

# %% [markdown]
# | DATA SCIENCE TOOLS |
# |--------------------|
# | JUPYTER.           |
# | R.                 |
# | VSCODE.            |

# %% [markdown]
# ### Below are a few examples of arithemtic expression used in python

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# #####This is a simple arithmetic expression to add and multiply integers.

# %%
minutes = 200
hours = minutes/60
hours =
# Out:
# 3.3333333333333335

# %% [markdown]
# This convert minutes to hours by divinding by 60

# %% [markdown]
# **OBJECTIVES**
#
# - IN THIS NOTEBOOK WE HAVE COVERED SOME OF THE POPULAR LANGUAGES
#
# - LIBRARIES THAT ARE MOST COMMONLY USED BY DATA SCIENTIST
#
# - WE HAVE LEARNED HOW TO MULTIPLY ADD AND DIVIDE INTEGERS
#
# - ALSO CREATED A TABLE OF DATA SCIENCE TOOLS

# %% [markdown]
# **AUTHOR**
#
# Laxmikanti saha
